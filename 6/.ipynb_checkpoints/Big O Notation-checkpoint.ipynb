# %%
def thing(N):
    i = N
    j = 1
    count = 0
    while j<i:
        i *= 100
        j *= 101
        count += 1
    return count

# %%
trials = [10, 100, 300, 500, 1000]
results = [thing(x) for x in trials]
trials
results
# Out:
# [232, 463, 574, 625, 695]

# %%
import matplotlib.pyplot as plt

plt.plot(trials, results)
plt.show()

# %%
def thing2(N):
    count = 0
    i = 0
    j = 1
    while i<N:
        for k in range(j):
            i += 1
            count += 1
        j *= 2
    return count

# %%
trials = [10, 100, 300, 500, 1000, 5000, 10000]
results = [thing2(x) for x in trials]
results
# Out:
# [15, 127, 511, 511, 1023, 8191, 16383]

# %%
plt.plot(trials, results)
plt.show()

# %%
def func(i):
    if i<1:
        return 1
    else:
        return func(i-1) + func(i-1)

# %%
trials = [10, 100, 300, 500, 1000]
results = [func(x) for x in trials]
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-96452b53f4b3> in <module>()
#       1 trials = [10, 100, 300, 500, 1000]
# ----> 2 results = [func(x) for x in trials]
#       3 results
#
# <ipython-input-11-96452b53f4b3> in <listcomp>(.0)
#       1 trials = [10, 100, 300, 500, 1000]
# ----> 2 results = [func(x) for x in trials]
#       3 results
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
#       3         return 1
#       4     else:
# ----> 5         return func(i-1) + func(i-1)
#
# <ipython-input-10-499572f46125> in func(i)
# ----> 1 def func(i):
#       2     if i<1:
#       3         return 1
#       4     else:
#       5         return func(i-1) + func(i-1)
#
# KeyboardInterrupt:

# %%
mb_list = [3,6,7,4,1,0,8,2,5]

def thing(N):
    count = 0
    n = len(mb_list)
    while mb_list != [0,1,2,3,4,5,6,7,8]:
        if mb_list[0] > mb_list[1]:
            if mb_list[1] == 0:
                mb_list[:n-1], mb_list[n-1] = mb_list[1:n], mb_list[0]
            else:
                mb_list[0], mb_list[1] = mb_list[1], mb_list[0]
        else:
            mb_list[:n-1], mb_list[n-1] = mb_list[1:n], mb_list[0]
        count += 1
